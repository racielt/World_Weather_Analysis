# %%
# Import the dependencies.
import pandas as pd
import gmaps
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_name = city
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | manzhouli
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | montrose
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | sao paulo de olivenca
# Processing Record 8 of Set 1 | adrar
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | gornozavodsk
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | new norfolk
# Processing Record 19 of Set 1 | madimba
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | nouadhibou
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | melilla
# Processing Record 24 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | ostrovnoy
# Processing Record 27 of Set 1 | narsaq
# Processing Record 28 of Set 1 | jorhat
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | sena madureira
# Processing Record 31 of Set 1 | berlevag
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | rize
# Processing Record 34 of Set 1 | payson
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | katsuura
# Processing Record 37 of Set 1 | parauna
# Processing Record 38 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | pisco
# Processing Record 41 of Set 1 | tabriz
# Processing Record 42 of Set 1 | husavik
# Processing Record 43 of Set 1 | lasa
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | vestmannaeyjar
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | high rock
# Processing Record 4 of Set 2 | prattville
# Processing Record 5 of Set 2 | yar-sale
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | honiara
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | airai
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | brae
# Processing Record 16 of Set 2 | mackay
# Processing Record 17 of Set 2 | mataura
# Processing Record 18 of Set 2 | gazalkent
# Processing Record 19 of Set 2 | toppenish
# Processing Record 20 of Set 2 | lethem
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 2 | suntar
# Processing Record 24 of Set 2 | goya
# Processing Record 25 of Set 2 | zhezkazgan
# Processing Record 26 of Set 2 | fort nelson
# Processing Record 27 of Set 2 | cooma
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | kapaa
# Processing Record 30 of Set 2 | nikolskoye
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | volax
# Processing Record 33 of Set 2 | radomsko
# Processing Record 34 of Set 2 | bermeo
# Processing Record 35 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 2 | vila velha
# Processing Record 37 of Set 2 | lagoa
# Processing Record 38 of Set 2 | ribeira grande
# Processing Record 39 of Set 2 | port-gentil
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | baracoa
# Processing Record 42 of Set 2 | amot
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | hofn
# Processing Record 47 of Set 2 | camacha
# Processing Record 48 of Set 2 | ryki
# Processing Record 49 of Set 2 | tuatapere
# Processing Record 50 of Set 2 | aklavik
# Processing Record 1 of Set 3 | freetown
# Processing Record 2 of Set 3 | lesosibirsk
# Processing Record 3 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 3 | gazojak
# Processing Record 5 of Set 3 | luderitz
# Processing Record 6 of Set 3 | lachhmangarh
# Processing Record 7 of Set 3 | alice springs
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | margate
# Processing Record 10 of Set 3 | astoria
# Processing Record 11 of Set 3 | sobolevo
# Processing Record 12 of Set 3 | krasne
# Processing Record 13 of Set 3 | coihaique
# Processing Record 14 of Set 3 | vardo
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | idil
# Processing Record 17 of Set 3 | cap malheureux
# Processing Record 18 of Set 3 | seafield
# Processing Record 19 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | tura
# Processing Record 23 of Set 3 | hambantota
# Processing Record 24 of Set 3 | nurota
# Processing Record 25 of Set 3 | chimore
# Processing Record 26 of Set 3 | nemuro
# Processing Record 27 of Set 3 | price
# Processing Record 28 of Set 3 | pathanamthitta
# Processing Record 29 of Set 3 | tucurui
# Processing Record 30 of Set 3 | carnarvon
# Processing Record 31 of Set 3 | san vicente
# Processing Record 32 of Set 3 | kozhva
# Processing Record 33 of Set 3 | novyy urgal
# Processing Record 34 of Set 3 | sao miguel do araguaia
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | mar del plata
# Processing Record 37 of Set 3 | marquette
# Processing Record 38 of Set 3 | bay-khaak
# Processing Record 39 of Set 3 | kindersley
# Processing Record 40 of Set 3 | hasaki
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | deputatskiy
# Processing Record 44 of Set 3 | ocosingo
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | bonfim
# Processing Record 47 of Set 3 | kavieng
# Processing Record 48 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 3 | half moon bay
# Processing Record 50 of Set 3 | itarema
# Processing Record 1 of Set 4 | conway
# Processing Record 2 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 4 | codigoro
# Processing Record 4 of Set 4 | ambilobe
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | sao jose do calcado
# Processing Record 7 of Set 4 | lalmohan
# Processing Record 8 of Set 4 | hirado
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | fushun
# Processing Record 11 of Set 4 | vostochnyy
# Processing Record 12 of Set 4 | carupano
# Processing Record 13 of Set 4 | barrow
# Processing Record 14 of Set 4 | bubaque
# Processing Record 15 of Set 4 | puerto ayora
# Processing Record 16 of Set 4 | nanortalik
# Processing Record 17 of Set 4 | kijang
# Processing Record 18 of Set 4 | la ronge
# Processing Record 19 of Set 4 | khuzdar
# Processing Record 20 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | arima
# Processing Record 22 of Set 4 | provideniya
# Processing Record 23 of Set 4 | namibe
# Processing Record 24 of Set 4 | freeport
# Processing Record 25 of Set 4 | shibganj
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | kalmunai
# Processing Record 28 of Set 4 | stephenville
# Processing Record 29 of Set 4 | cahors
# Processing Record 30 of Set 4 | plettenberg bay
# Processing Record 31 of Set 4 | mariental
# Processing Record 32 of Set 4 | hermanus
# Processing Record 33 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 34 of Set 4 | tasiilaq
# Processing Record 35 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | faya
# Processing Record 38 of Set 4 | college
# Processing Record 39 of Set 4 | kousseri
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | sao joao da barra
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 4 | dover
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | makakilo city
# Processing Record 47 of Set 4 | shahrud
# Processing Record 48 of Set 4 | lawigan
# Processing Record 49 of Set 4 | thinadhoo
# Processing Record 50 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 1 of Set 5 | hailar
# Processing Record 2 of Set 5 | sorland
# Processing Record 3 of Set 5 | krabi
# Processing Record 4 of Set 5 | agirish
# Processing Record 5 of Set 5 | tacoronte
# Processing Record 6 of Set 5 | kiama
# Processing Record 7 of Set 5 | kuytun
# Processing Record 8 of Set 5 | marovoay
# Processing Record 9 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 10 of Set 5 | tres arroyos
# Processing Record 11 of Set 5 | nusaybin
# Processing Record 12 of Set 5 | solvychegodsk
# Processing Record 13 of Set 5 | atar
# Processing Record 14 of Set 5 | shubarshi
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | san cristobal
# Processing Record 17 of Set 5 | dinan
# Processing Record 18 of Set 5 | inuvik
# Processing Record 19 of Set 5 | talaya
# Processing Record 20 of Set 5 | alofi
# Processing Record 21 of Set 5 | georgetown
# Processing Record 22 of Set 5 | hualmay
# Processing Record 23 of Set 5 | curup
# Processing Record 24 of Set 5 | torbay
# Processing Record 25 of Set 5 | buraydah
# Processing Record 26 of Set 5 | krasnoselkup
# Processing Record 27 of Set 5 | orlik
# Processing Record 28 of Set 5 | aleksandrov gay
# Processing Record 29 of Set 5 | roald
# Processing Record 30 of Set 5 | artyom
# Processing Record 31 of Set 5 | adelaide
# Processing Record 32 of Set 5 | tetelzingo
# Processing Record 33 of Set 5 | sambava
# Processing Record 34 of Set 5 | hami
# Processing Record 35 of Set 5 | dobson
# Processing Record 36 of Set 5 | seoul
# Processing Record 37 of Set 5 | bangassou
# Processing Record 38 of Set 5 | mocuba
# Processing Record 39 of Set 5 | olafsvik
# Processing Record 40 of Set 5 | gauting
# Processing Record 41 of Set 5 | dingle
# Processing Record 42 of Set 5 | posse
# Processing Record 43 of Set 5 | iquique
# Processing Record 44 of Set 5 | huilong
# Processing Record 45 of Set 5 | onguday
# Processing Record 46 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 5 | severo-kurilsk
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | zabaykalsk
# Processing Record 50 of Set 5 | broome
# Processing Record 1 of Set 6 | tsiroanomandidy
# Processing Record 2 of Set 6 | sao filipe
# Processing Record 3 of Set 6 | methoni
# Processing Record 4 of Set 6 | beringovskiy
# Processing Record 5 of Set 6 | flinders
# Processing Record 6 of Set 6 | harwich
# Processing Record 7 of Set 6 | tambovka
# Processing Record 8 of Set 6 | mount isa
# Processing Record 9 of Set 6 | oranjestad
# Processing Record 10 of Set 6 | sola
# Processing Record 11 of Set 6 | isabela
# Processing Record 12 of Set 6 | banjar
# Processing Record 13 of Set 6 | marmora
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | zorritos
# Processing Record 16 of Set 6 | manta
# Processing Record 17 of Set 6 | verkhnyaya khava
# Processing Record 18 of Set 6 | rabo de peixe
# Processing Record 19 of Set 6 | clyde
# Processing Record 20 of Set 6 | nizwa
# Processing Record 21 of Set 6 | rundu
# Processing Record 22 of Set 6 | mayo
# Processing Record 23 of Set 6 | houston
# Processing Record 24 of Set 6 | voi
# Processing Record 25 of Set 6 | pevek
# Processing Record 26 of Set 6 | nyandoma
# Processing Record 27 of Set 6 | tongliao
# Processing Record 28 of Set 6 | litoral del san juan
# City not found. Skipping...
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | itaituba
# Processing Record 31 of Set 6 | orcopampa
# Processing Record 32 of Set 6 | orichi
# Processing Record 33 of Set 6 | castro
# Processing Record 34 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 6 | saint-pierre
# Processing Record 36 of Set 6 | santa rosa
# Processing Record 37 of Set 6 | natal
# Processing Record 38 of Set 6 | manokwari
# Processing Record 39 of Set 6 | udachnyy
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | bozdar
# Processing Record 42 of Set 6 | leshukonskoye
# Processing Record 43 of Set 6 | nizhnyaya tavda
# Processing Record 44 of Set 6 | sumbawanga
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | susanino
# Processing Record 48 of Set 6 | lata
# Processing Record 49 of Set 6 | salinopolis
# Processing Record 50 of Set 6 | cam ranh
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | znamenskoye
# Processing Record 3 of Set 7 | longyearbyen
# Processing Record 4 of Set 7 | nanakuli
# Processing Record 5 of Set 7 | port-cartier
# Processing Record 6 of Set 7 | nsanje
# Processing Record 7 of Set 7 | jimma
# Processing Record 8 of Set 7 | bambous virieux
# Processing Record 9 of Set 7 | kedrovyy
# Processing Record 10 of Set 7 | svetlaya
# Processing Record 11 of Set 7 | vera cruz
# Processing Record 12 of Set 7 | ladario
# Processing Record 13 of Set 7 | osorno
# Processing Record 14 of Set 7 | armizonskoye
# Processing Record 15 of Set 7 | mahebourg
# Processing Record 16 of Set 7 | carutapera
# Processing Record 17 of Set 7 | praia
# Processing Record 18 of Set 7 | richards bay
# Processing Record 19 of Set 7 | port augusta
# Processing Record 20 of Set 7 | gigmoto
# Processing Record 21 of Set 7 | jarjis
# City not found. Skipping...
# Processing Record 22 of Set 7 | san patricio
# Processing Record 23 of Set 7 | jiuquan
# Processing Record 24 of Set 7 | clyde river
# Processing Record 25 of Set 7 | oksovskiy
# Processing Record 26 of Set 7 | camana
# Processing Record 27 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 7 | mendi
# Processing Record 29 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 30 of Set 7 | wodzislaw slaski
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | meulaboh
# Processing Record 33 of Set 7 | sindor
# Processing Record 34 of Set 7 | atlantic city
# Processing Record 35 of Set 7 | tual
# Processing Record 36 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 37 of Set 7 | jaumave
# Processing Record 38 of Set 7 | rincon
# Processing Record 39 of Set 7 | santa cruz
# Processing Record 40 of Set 7 | cabo san lucas
# Processing Record 41 of Set 7 | bangui
# Processing Record 42 of Set 7 | vanavara
# Processing Record 43 of Set 7 | san isidro
# Processing Record 44 of Set 7 | kodiak
# Processing Record 45 of Set 7 | port elizabeth
# Processing Record 46 of Set 7 | lewisville
# Processing Record 47 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | faanui
# Processing Record 49 of Set 7 | colac
# Processing Record 50 of Set 7 | oyama
# Processing Record 1 of Set 8 | palana
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 8 | siocon
# Processing Record 4 of Set 8 | esperance
# Processing Record 5 of Set 8 | chinsali
# Processing Record 6 of Set 8 | debre zeyit
# Processing Record 7 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 8 of Set 8 | severodvinsk
# Processing Record 9 of Set 8 | barstow
# Processing Record 10 of Set 8 | kolondieba
# Processing Record 11 of Set 8 | vaitape
# Processing Record 12 of Set 8 | songea
# Processing Record 13 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 14 of Set 8 | mana
# Processing Record 15 of Set 8 | axim
# Processing Record 16 of Set 8 | bethanien
# Processing Record 17 of Set 8 | imeni zhelyabova
# Processing Record 18 of Set 8 | mareeba
# Processing Record 19 of Set 8 | gat
# Processing Record 20 of Set 8 | aranos
# Processing Record 21 of Set 8 | anchorage
# Processing Record 22 of Set 8 | san quintin
# Processing Record 23 of Set 8 | jacareacanga
# Processing Record 24 of Set 8 | gamboma
# Processing Record 25 of Set 8 | hire
# City not found. Skipping...
# Processing Record 26 of Set 8 | mitzic
# Processing Record 27 of Set 8 | naze
# Processing Record 28 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 8 | kalanguy
# Processing Record 30 of Set 8 | shimoda
# Processing Record 31 of Set 8 | akdepe
# Processing Record 32 of Set 8 | roma
# Processing Record 33 of Set 8 | andros town
# Processing Record 34 of Set 8 | cuenca
# Processing Record 35 of Set 8 | schonebeck
# Processing Record 36 of Set 8 | le passage
# Processing Record 37 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 8 | novo horizonte
# Processing Record 39 of Set 8 | miri
# Processing Record 40 of Set 8 | novi sanzhary
# Processing Record 41 of Set 8 | geraldton
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | kropotkin
# Processing Record 44 of Set 8 | berdigestyakh
# Processing Record 45 of Set 8 | san jeronimo
# Processing Record 46 of Set 8 | marzuq
# Processing Record 47 of Set 8 | los llanos de aridane
# Processing Record 48 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 49 of Set 8 | north bend
# Processing Record 50 of Set 8 | sinnamary
# Processing Record 1 of Set 9 | amga
# Processing Record 2 of Set 9 | tazovskiy
# Processing Record 3 of Set 9 | belmonte
# Processing Record 4 of Set 9 | olinda
# Processing Record 5 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 9 | saint-georges
# Processing Record 7 of Set 9 | oranjemund
# Processing Record 8 of Set 9 | maragogi
# Processing Record 9 of Set 9 | la rioja
# Processing Record 10 of Set 9 | brigantine
# Processing Record 11 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 12 of Set 9 | tanabe
# Processing Record 13 of Set 9 | zhigansk
# Processing Record 14 of Set 9 | orange cove
# Processing Record 15 of Set 9 | lagos
# Processing Record 16 of Set 9 | manavalakurichi
# Processing Record 17 of Set 9 | catamarca
# Processing Record 18 of Set 9 | ancud
# Processing Record 19 of Set 9 | goundam
# Processing Record 20 of Set 9 | bengkulu
# Processing Record 21 of Set 9 | machacamarca
# Processing Record 22 of Set 9 | guilin
# Processing Record 23 of Set 9 | bol
# Processing Record 24 of Set 9 | hasanabad
# Processing Record 25 of Set 9 | yeniseysk
# Processing Record 26 of Set 9 | kawalu
# Processing Record 27 of Set 9 | khvalynsk
# Processing Record 28 of Set 9 | grand-santi
# Processing Record 29 of Set 9 | ilhabela
# Processing Record 30 of Set 9 | yumen
# Processing Record 31 of Set 9 | linxia
# Processing Record 32 of Set 9 | nuuk
# Processing Record 33 of Set 9 | gilgit
# Processing Record 34 of Set 9 | rafai
# Processing Record 35 of Set 9 | acapulco
# Processing Record 36 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint-francois
# Processing Record 38 of Set 9 | marana
# Processing Record 39 of Set 9 | altamira
# Processing Record 40 of Set 9 | chowchilla
# Processing Record 41 of Set 9 | wageningen
# Processing Record 42 of Set 9 | kirakira
# Processing Record 43 of Set 9 | lander
# Processing Record 44 of Set 9 | sakakah
# Processing Record 45 of Set 9 | ust-nera
# Processing Record 46 of Set 9 | nome
# Processing Record 47 of Set 9 | port moresby
# Processing Record 48 of Set 9 | kalavrita
# City not found. Skipping...
# Processing Record 49 of Set 9 | labuhan
# Processing Record 50 of Set 9 | bethel
# Processing Record 1 of Set 10 | parana
# Processing Record 2 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 10 | moranbah
# Processing Record 4 of Set 10 | auki
# Processing Record 5 of Set 10 | pangnirtung
# Processing Record 6 of Set 10 | samfya
# Processing Record 7 of Set 10 | kashi
# Processing Record 8 of Set 10 | edd
# Processing Record 9 of Set 10 | mehamn
# Processing Record 10 of Set 10 | magadan
# Processing Record 11 of Set 10 | klaksvik
# Processing Record 12 of Set 10 | maxixe
# Processing Record 13 of Set 10 | benguela
# Processing Record 14 of Set 10 | pacific grove
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | itoman
# Processing Record 17 of Set 10 | shahapur
# Processing Record 18 of Set 10 | tautira
# Processing Record 19 of Set 10 | san rafael
# Processing Record 20 of Set 10 | boundiali
# Processing Record 21 of Set 10 | inhambane
# Processing Record 22 of Set 10 | rawson
# Processing Record 23 of Set 10 | nelson bay
# Processing Record 24 of Set 10 | saint paul
# Processing Record 25 of Set 10 | eufaula
# Processing Record 26 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 10 | tiksi
# Processing Record 28 of Set 10 | saqqez
# Processing Record 29 of Set 10 | inongo
# Processing Record 30 of Set 10 | kastamonu
# Processing Record 31 of Set 10 | north myrtle beach
# Processing Record 32 of Set 10 | vung tau
# Processing Record 33 of Set 10 | mount gambier
# Processing Record 34 of Set 10 | phan thiet
# Processing Record 35 of Set 10 | thana
# Processing Record 36 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | mentok
# City not found. Skipping...
# Processing Record 39 of Set 10 | ponta delgada
# Processing Record 40 of Set 10 | takefu
# Processing Record 41 of Set 10 | kiunga
# Processing Record 42 of Set 10 | taywarah
# Processing Record 43 of Set 10 | gamba
# Processing Record 44 of Set 10 | yunyang
# Processing Record 45 of Set 10 | nadvoitsy
# Processing Record 46 of Set 10 | hargeysa
# Processing Record 47 of Set 10 | luis correia
# Processing Record 48 of Set 10 | arequipa
# Processing Record 49 of Set 10 | atambua
# Processing Record 50 of Set 10 | constitucion
# Processing Record 1 of Set 11 | locri
# Processing Record 2 of Set 11 | tuy hoa
# Processing Record 3 of Set 11 | suihua
# Processing Record 4 of Set 11 | khuzhir
# Processing Record 5 of Set 11 | lincoln
# Processing Record 6 of Set 11 | paamiut
# Processing Record 7 of Set 11 | bud
# Processing Record 8 of Set 11 | bandarbeyla
# Processing Record 9 of Set 11 | buzmeyin
# Processing Record 10 of Set 11 | kununurra
# Processing Record 11 of Set 11 | korem
# Processing Record 12 of Set 11 | waitati
# Processing Record 13 of Set 11 | rocha
# Processing Record 14 of Set 11 | timra
# Processing Record 15 of Set 11 | nikolayevsk-na-amure
# Processing Record 16 of Set 11 | gorontalo
# Processing Record 17 of Set 11 | barinas
# Processing Record 18 of Set 11 | luwuk
# Processing Record 19 of Set 11 | mersing
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | yulara
# Processing Record 22 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 11 | padang
# Processing Record 24 of Set 11 | namie
# Processing Record 25 of Set 11 | ambunti
# Processing Record 26 of Set 11 | vila franca do campo
# Processing Record 27 of Set 11 | khailar
# Processing Record 28 of Set 11 | kars
# Processing Record 29 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 30 of Set 11 | sanmenxia
# Processing Record 31 of Set 11 | grand island
# Processing Record 32 of Set 11 | deep river
# Processing Record 33 of Set 11 | escanaba
# Processing Record 34 of Set 11 | ornskoldsvik
# Processing Record 35 of Set 11 | sharan
# Processing Record 36 of Set 11 | kumi
# Processing Record 37 of Set 11 | bereda
# Processing Record 38 of Set 11 | kenai
# Processing Record 39 of Set 11 | black river
# Processing Record 40 of Set 11 | santa isabel do rio negro
# Processing Record 41 of Set 11 | rudnogorsk
# Processing Record 42 of Set 11 | bundoran
# Processing Record 43 of Set 11 | huarmey
# Processing Record 44 of Set 11 | bonavista
# Processing Record 45 of Set 11 | banting
# Processing Record 46 of Set 11 | san policarpo
# Processing Record 47 of Set 11 | norman wells
# Processing Record 48 of Set 11 | esso
# Processing Record 49 of Set 11 | rio grande
# Processing Record 50 of Set 11 | punta alta
# Processing Record 1 of Set 12 | mahibadhoo
# Processing Record 2 of Set 12 | iralaya
# Processing Record 3 of Set 12 | shimanovsk
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | fortuna
# Processing Record 6 of Set 12 | komsomolskiy
# Processing Record 7 of Set 12 | livingstone
# Processing Record 8 of Set 12 | caucaia
# Processing Record 9 of Set 12 | izhmorskiy
# Processing Record 10 of Set 12 | sistranda
# Processing Record 11 of Set 12 | libreville
# Processing Record 12 of Set 12 | kaeo
# Processing Record 13 of Set 12 | susanville
# Processing Record 14 of Set 12 | beyneu
# Processing Record 15 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 12 | carbonia
# Processing Record 18 of Set 12 | ofaqim
# Processing Record 19 of Set 12 | sao francisco
# Processing Record 20 of Set 12 | mecca
# Processing Record 21 of Set 12 | teahupoo
# Processing Record 22 of Set 12 | choszczno
# Processing Record 23 of Set 12 | pinotepa nacional
# Processing Record 24 of Set 12 | kloulklubed
# Processing Record 25 of Set 12 | homer
# Processing Record 26 of Set 12 | lidorikion
# City not found. Skipping...
# Processing Record 27 of Set 12 | henties bay
# Processing Record 28 of Set 12 | arlit
# Processing Record 29 of Set 12 | stornoway
# Processing Record 30 of Set 12 | saint-leu
# Processing Record 31 of Set 12 | belyy yar
# Processing Record 32 of Set 12 | mantsala
# Processing Record 33 of Set 12 | iqaluit
# Processing Record 34 of Set 12 | kieta
# Processing Record 35 of Set 12 | menomonie
# Processing Record 36 of Set 12 | san miguel
# Processing Record 37 of Set 12 | waipawa
# Processing Record 38 of Set 12 | victoria
# Processing Record 39 of Set 12 | berezovyy
# Processing Record 40 of Set 12 | banda aceh
# Processing Record 41 of Set 12 | tabuk
# Processing Record 42 of Set 12 | teya
# Processing Record 43 of Set 12 | junin
# Processing Record 44 of Set 12 | maues
# Processing Record 45 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 12 | kantang
# Processing Record 47 of Set 12 | lantawan
# Processing Record 48 of Set 12 | kostomuksha
# Processing Record 49 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 13 | mahanoro
# Processing Record 2 of Set 13 | kholm
# Processing Record 3 of Set 13 | pinheiro machado
# Processing Record 4 of Set 13 | benjamin constant
# Processing Record 5 of Set 13 | campbell river
# Processing Record 6 of Set 13 | santo antonio do amparo
# Processing Record 7 of Set 13 | khowst
# Processing Record 8 of Set 13 | alappuzha
# Processing Record 9 of Set 13 | cockburn town
# Processing Record 10 of Set 13 | pilao arcado
# City not found. Skipping...
# Processing Record 11 of Set 13 | caravelas
# Processing Record 12 of Set 13 | kruisfontein
# Processing Record 13 of Set 13 | baie-comeau
# Processing Record 14 of Set 13 | muzhi
# Processing Record 15 of Set 13 | rosarito
# Processing Record 16 of Set 13 | kerman
# Processing Record 17 of Set 13 | kerema
# Processing Record 18 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 13 | igrim
# Processing Record 21 of Set 13 | noumea
# Processing Record 22 of Set 13 | ulagan
# Processing Record 23 of Set 13 | saldanha
# Processing Record 24 of Set 13 | praia da vitoria
# Processing Record 25 of Set 13 | palora
# Processing Record 26 of Set 13 | bonga
# Processing Record 27 of Set 13 | luleburgaz
# Processing Record 28 of Set 13 | aparecida do taboado
# Processing Record 29 of Set 13 | beira
# Processing Record 30 of Set 13 | saint-michel-des-saints
# Processing Record 31 of Set 13 | baykit
# Processing Record 32 of Set 13 | xuddur
# Processing Record 33 of Set 13 | jalu
# Processing Record 34 of Set 13 | qui nhon
# Processing Record 35 of Set 13 | santa maria
# Processing Record 36 of Set 13 | yabelo
# Processing Record 37 of Set 13 | shubarkuduk
# Processing Record 38 of Set 13 | lithgow
# Processing Record 39 of Set 13 | mogadishu
# Processing Record 40 of Set 13 | port macquarie
# Processing Record 41 of Set 13 | poya
# Processing Record 42 of Set 13 | sabang
# Processing Record 43 of Set 13 | nanga eboko
# Processing Record 44 of Set 13 | pangody
# Processing Record 45 of Set 13 | sabana de torres
# Processing Record 46 of Set 13 | ahuimanu
# Processing Record 47 of Set 13 | san jose de sisa
# Processing Record 48 of Set 13 | kon tum
# Processing Record 49 of Set 13 | hershey
# Processing Record 50 of Set 13 | cayenne
# Processing Record 1 of Set 14 | jining
# Processing Record 2 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 3 of Set 14 | palu
# Processing Record 4 of Set 14 | biella
# Processing Record 5 of Set 14 | port blair
# Processing Record 6 of Set 14 | raymond
# Processing Record 7 of Set 14 | muli
# Processing Record 8 of Set 14 | kharhial
# Processing Record 9 of Set 14 | qostanay
# Processing Record 10 of Set 14 | belaya gora
# Processing Record 11 of Set 14 | corinto
# Processing Record 12 of Set 14 | yamada
# Processing Record 13 of Set 14 | mapimi
# Processing Record 14 of Set 14 | platteville
# Processing Record 15 of Set 14 | havoysund
# Processing Record 16 of Set 14 | broken hill
# Processing Record 17 of Set 14 | yelizovo
# Processing Record 18 of Set 14 | boguchany
# Processing Record 19 of Set 14 | aykhal
# Processing Record 20 of Set 14 | burica
# City not found. Skipping...
# Processing Record 21 of Set 14 | loandjili
# Processing Record 22 of Set 14 | kulhudhuffushi
# Processing Record 23 of Set 14 | pulaski
# Processing Record 24 of Set 14 | bhatkal
# Processing Record 25 of Set 14 | requena
# Processing Record 26 of Set 14 | erdenet
# Processing Record 27 of Set 14 | mantua
# Processing Record 28 of Set 14 | necochea
# Processing Record 29 of Set 14 | fethiye
# Processing Record 30 of Set 14 | bull savanna
# Processing Record 31 of Set 14 | murray bridge
# Processing Record 32 of Set 14 | denia
# Processing Record 33 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 34 of Set 14 | byron bay
# Processing Record 35 of Set 14 | dasoguz
# Processing Record 36 of Set 14 | boralday
# Processing Record 37 of Set 14 | yanam
# Processing Record 38 of Set 14 | agadir
# Processing Record 39 of Set 14 | frontera
# Processing Record 40 of Set 14 | lieksa
# Processing Record 41 of Set 14 | nizhniy kuranakh
# Processing Record 42 of Set 14 | eureka
# Processing Record 43 of Set 14 | preobrazheniye
# Processing Record 44 of Set 14 | urengoy
# Processing Record 45 of Set 14 | mabaruma
# Processing Record 46 of Set 14 | te anau
# Processing Record 47 of Set 14 | bogorodskoye
# Processing Record 48 of Set 14 | pudozh
# Processing Record 49 of Set 14 | da lat
# Processing Record 50 of Set 14 | vagur
# Processing Record 1 of Set 15 | daru
# Processing Record 2 of Set 15 | pozoblanco
# Processing Record 3 of Set 15 | dali
# Processing Record 4 of Set 15 | camopi
# Processing Record 5 of Set 15 | grants pass
# Processing Record 6 of Set 15 | comodoro rivadavia
# Processing Record 7 of Set 15 | porto novo
# Processing Record 8 of Set 15 | cabedelo
# Processing Record 9 of Set 15 | shaoguan
# Processing Record 10 of Set 15 | dhidhdhoo
# Processing Record 11 of Set 15 | moron
# Processing Record 12 of Set 15 | gura teghii
# Processing Record 13 of Set 15 | maningrida
# Processing Record 14 of Set 15 | monte carmelo
# Processing Record 15 of Set 15 | bridlington
# Processing Record 16 of Set 15 | kodinsk
# Processing Record 17 of Set 15 | koungheul
# Processing Record 18 of Set 15 | zelenoborskiy
# Processing Record 19 of Set 15 | bowen
# Processing Record 20 of Set 15 | fairbanks
# Processing Record 21 of Set 15 | bardiyah
# Processing Record 22 of Set 15 | qasigiannguit
# Processing Record 23 of Set 15 | doha
# Processing Record 24 of Set 15 | mulege
# Processing Record 25 of Set 15 | sandwick
# Processing Record 26 of Set 15 | springfield
# Processing Record 27 of Set 15 | gizo
# Processing Record 28 of Set 15 | kabalo
# Processing Record 29 of Set 15 | gold coast
# Processing Record 30 of Set 15 | foz
# Processing Record 31 of Set 15 | campo maior
# Processing Record 32 of Set 15 | peqin
# Processing Record 33 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 15 | rio gallegos
# Processing Record 35 of Set 15 | kutum
# Processing Record 36 of Set 15 | pastavy
# Processing Record 37 of Set 15 | staryy nadym
# Processing Record 38 of Set 15 | ternate
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 677

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Manzhouli  49.6000  117.4333     24.46        38           3
# 1                Kahului  20.8947 -156.4700     69.06        69           1
# 2               Montrose  38.4166 -108.2673     50.45        27           1
# 3                 Lompoc  34.6391 -120.4579     60.93        89          90
# 4                Qaanaaq  77.4840  -69.3632      2.53        51           0
# 5                  Vaini -21.2000 -175.2000     71.76        94          20
# 6  Sao Paulo De Olivenca  -3.3783  -68.8725     87.66        65          86
# 7                  Adrar  20.5022  -10.0711     86.29        12         100
# 8                   Hilo  19.7297 -155.0900     82.27        74           2
# 9                Ushuaia -54.8000  -68.3000     49.66        53           0
#
#    Wind Speed Country Current Description                 Date
# 0        3.22      CN           clear sky  2021-10-30 17:55:55
# 1        3.96      US           clear sky  2021-10-30 17:55:55
# 2        0.63      US           clear sky  2021-10-30 17:51:51
# 3        5.75      US     overcast clouds  2021-10-30 17:55:55
# 4        8.25      GL           clear sky  2021-10-30 17:55:56
# 5        3.44      TO          few clouds  2021-10-30 17:55:56
# 6        2.06      BR     overcast clouds  2021-10-30 17:55:57
# 7        8.50      MR     overcast clouds  2021-10-30 17:55:57
# 8        0.45      US           clear sky  2021-10-30 17:55:57
# 9       13.80      AR           clear sky  2021-10-30 17:55:58

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Manzhouli      CN  49.6000  117.4333     24.46        38           3
# 1         Kahului      US  20.8947 -156.4700     69.06        69           1
# 2        Montrose      US  38.4166 -108.2673     50.45        27           1
# 3          Lompoc      US  34.6391 -120.4579     60.93        89          90
# 4         Qaanaaq      GL  77.4840  -69.3632      2.53        51           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 672  Rio Gallegos      AR -51.6226  -69.2181     59.05        21           0
# 673         Kutum      SD  14.2000   24.6667     79.39        14          16
# 674       Pastavy      BY  55.1168   26.8326     49.75        71           8
# 675  Staryy Nadym      RU  65.6118   72.6842     10.35        92         100
# 676       Ternate      ID   0.8000  127.4000     79.88        82         100
#
#      Wind Speed Current Description
# 0          3.22           clear sky
# 1          3.96           clear sky
# 2          0.63           clear sky
# 3          5.75     overcast clouds
# 4          8.25           clear sky
# ..          ...                 ...
# 672       16.11           clear sky
# 673        5.64          few clouds
# 674       14.03           clear sky
# 675       18.19     overcast clouds
# 676        2.64          light rain
#
# [677 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
